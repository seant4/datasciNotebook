# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_feat = np.arange(0,50,2)
y_feat = np.arange(0,50,2)
[X, Y] = np.meshgrid(x_feat, y_feat)
Z = (X**2)+(Y**2)

# %%
fig, ax = plt.subplots(1,1)
ax.contour(X,Y,Z)
